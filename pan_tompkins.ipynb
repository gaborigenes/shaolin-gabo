# %% [markdown]
# <a href="https://colab.research.google.com/github/gaborigenes/shaolin-gabo/blob/master/pan_tompkins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Código**
# ### **Descargar el conjunto de datos**

# %%
# !pip -q install wfdb==3.4.0
# !wget -q https://physionet.org/files/afpdb/1.0.0/

# %%
import wfdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

archivo = f'/content/physionet.org/files/afpdb/1.0.0/p01c'
registro = wfdb.rdrecord(archivo, sampfrom=180, sampto=4000,)    
anotacion = wfdb.rdann(archivo, 'dat', sampfrom=180, sampto=4000,shift_samps=True)
wfdb.plot_wfdb(record=registro, annotation=anotacion, time_units='seconds',figsize=(20,10))
